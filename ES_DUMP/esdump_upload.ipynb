# %%
import json

# %%
import json
import pandas as pd
import json
import requests
count=1
data = pd.DataFrame()
with open('tutorials.json') as f:
    for line in f:
        data=json.loads(line)['_source']
        print(data)
        topic=data['topic']
        title=data['title']
        url=data['url']
        labels=data['labels']
        upvotes=data['upvote']
        post_url = "http://localhost:9200/hacker/"
        post_autocomplete_url ="http://localhost:9200/autocomplete/"
        payload ={
            "upvote":int(upvotes),
            "topic":topic,
            "title":title,
            "url":url,
            "labels":labels
        }
        payload_autocomplete={
            "title": title,
            "title_suggest":title
        }

        headers = {
            'Content-Type': "application/json",
            'cache-control': "no-cache"
        }
        
        payload = json.dumps(payload)
        res = es.index(index="hacker",  body=payload)
        print(res)
        payload_autocomplete = json.dumps(payload_autocomplete)
        res = es.index(index="autocomplete",  body=payload_autocomplete)
        print(res)


        print("----------------", count, "----------------------")
        count = count + 1
# Out:
# {'upvote': 100, 'topic': 'Android Development', 'title': 'The Complete Android N Developer Course', 'url': 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=39197&murl=https://www.udemy.com/complete-android-n-developer-course/', 'labels': ['Paid', 'Video', 'Beginner', 'Android 7 — Nougat']}
# {'_index': 'hacker', '_type': '_doc', '_id': 'u5LwJnsBK31UovpiRAya', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# {'_index': 'autocomplete', '_type': '_doc', '_id': 'vJLwJnsBK31UovpiRAz3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# ---------------- 1 ----------------------
# {'upvote': 50, 'topic': 'Android Development', 'title': 'Android Material Design Tutorial', 'url': 'https://www.youtube.com/playlist?list=PLonJJ3BVjZW6CtAMbJz1XD8ELUs1KXaTD', 'labels': ['Free', 'Video']}
# ...

# %%
# !pip install elasticsearch

# %%
from datetime import datetime
from elasticsearch import Elasticsearch
es = Elasticsearch()

# %%
search={"query":{"match_all":{}}}
es.search(index="autocomplete", body=search)
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 0, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []}}
